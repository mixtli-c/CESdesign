# %%
import numpy as np
import datetime as dt
import scipy.signal as scs
import pandas as pd
import glob
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import sys
sys.path.append('D:\\gitCCA\\CESdesign\\py')
import CESfunctions_dev as cf

# %%
ramafolder = 'D:\\CCA\\Avantes\\BBCEAS_Data\\RAMA\\'
mfolder = 'D:\\CCA\\Avantes\\BBCEAS_Data\\'

ramafile1 = 'CCA_20220303_M.csv'
#ramafile2 = 'CCA_20220311_M.csv'

mfile1 = '20220303\\M2203031545.txt'

dateM1,ppb1M1,ppb2M1,intM1 = cf.Mfile_read(mfolder+mfile1)

dateR1,ppbR1 = cf.RAMA_read(ramafolder+ramafile1)

# %%
f = plt.figure(figsize=(8,6))
ax1 = f.add_subplot(111)
dateR1d=[]
for ele in dateR1:
    dateR1d.append(ele-dt.timedelta(minutes=8))

ax1.plot(dateM1,ppb1M1,'--k',alpha=0.25)
ax1.plot(dateM1,scs.savgol_filter(ppb1M1,21,3),'-k', label="BBCEAS")
ax1.plot(dateR1d[750:900],ppbR1[750:900],'-r', label="RAMA")
ax1.set_xlabel('Time',size=14)
ax1.set_ylabel('NO$_2$ ppb',size=14)
ax1.set_title("Measurements March 03 2022",size=16)
ax1.legend(fontsize=12, loc='upper left')
ax1.xaxis.set_major_formatter(DateFormatter("%H:%M:%S"))

# %%
zipped = list(zip(dateR1d,ppbR1))
df1 = pd.DataFrame(zipped, columns=['Date', 'NO2_RAMA'])
ts1=df1.set_index('Date')
zipped = list(zip(dateM1,ppb1M1))
df2 = pd.DataFrame(zipped, columns=['Date', 'NO2_CEAS'])
ts2=df2.set_index('Date')

# %%
ts2m=ts2.resample('T').mean()

# %%
tscommon = pd.merge(ts1, ts2m, how='inner', on=['Date'])
tscommon
# Out:
#                      NO2_RAMA   NO2_CEAS
# Date
# 2022-03-03 13:27:00     25.36  26.605893
# 2022-03-03 13:28:00     24.74  26.551902
# 2022-03-03 13:29:00     24.19  25.095659
# 2022-03-03 13:30:00     23.99  25.591706
# 2022-03-03 13:31:00     23.69  24.849774
# ...                       ...        ...
# 2022-03-03 15:41:00     11.23  13.346991
# 2022-03-03 15:42:00     10.84  10.506272
# 2022-03-03 15:43:00      9.87  10.548908
# 2022-03-03 15:44:00      9.65   6.321583
# 2022-03-03 15:45:00      9.74   8.334698
#
# [139 rows x 2 columns]

# %%
f = plt.figure(figsize=(8,6))
ax1 = f.add_subplot(111)

ax1.plot(tscommon.index,tscommon.NO2_CEAS,'-k',label="BBCEAS")
ax1.plot(tscommon.index,tscommon.NO2_RAMA,'-r', label="RAMA")
ax1.set_xlabel('Time',size=14)
ax1.set_ylabel('NO$_2$ ppb',size=14)
ax1.set_title("Measurements March 03 2022",size=16)
ax1.legend(fontsize=12, loc='upper left')
ax1.xaxis.set_major_formatter(DateFormatter("%H:%M:%S"))

# %%
f = plt.figure(figsize=(8,6))
ax1 = f.add_subplot(111)

ax1.plot(tscommon.NO2_RAMA,tscommon.NO2_CEAS,'.k')
ax1.set_xlabel('BBCEAS',size=14)
ax1.set_ylabel('RAMA',size=14)
ax1.set_title("Measurements March 03 2022",size=16)
# Out:
# Text(0.5, 1.0, 'Measurements March 03 2022')
